# %%
# Check PyTorch installation
import torch, torchvision
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 1.13.1+cu116
# True

# %%
# Clone mmcls repository and checkout to the 1.x branch
# !git clone -b 1.x https://github.com/open-mmlab/mmclassification.git
# %cd mmclassification/

# Install MMClassification from source by mim
# !pip install openmim
# !mim install -e .

# %%
# Check MMClassification installation
import mmcls
print(mmcls.__version__)
# Out:
# 1.0.0rc5

# %%
# Download the dataset (cats & dogs dataset)
# !wget https://www.dropbox.com/s/wml49yrtdo53mie/cats_dogs_dataset_reorg.zip?dl=0 -O cats_dogs_dataset.zip
# !mkdir -p data
# !unzip -q cats_dogs_dataset.zip -d ./data/

# %% [markdown]
# **After downloading and extraction,** we get "Cats and Dogs Dataset" and the file structure is as below:
# ```
# data/cats_dogs_dataset
# ├── classes.txt
# ├── test.txt
# ├── val.txt
# ├── training_set
# │   ├── training_set
# │   │   ├── cats
# │   │   │   ├── cat.1.jpg
# │   │   │   ├── cat.2.jpg
# │   │   │   ├── ...
# │   │   ├── dogs
# │   │   │   ├── dog.2.jpg
# │   │   │   ├── dog.3.jpg
# │   │   │   ├── ...
# ├── val_set
# │   ├── val_set
# │   │   ├── cats
# │   │   │   ├── cat.3.jpg
# │   │   │   ├── cat.5.jpg
# │   │   │   ├── ...
# │   │   ├── dogs
# │   │   │   ├── dog.1.jpg
# │   │   │   ├── dog.6.jpg
# │   │   │   ├── ...
# ├── test_set
# │   ├── test_set
# │   │   ├── cats
# │   │   │   ├── cat.4001.jpg
# │   │   │   ├── cat.4002.jpg
# │   │   │   ├── ...
# │   │   ├── dogs
# │   │   │   ├── dog.4001.jpg
# │   │   │   ├── dog.4002.jpg
# │   │   │   ├── ...
# ```
#
# You can use shell command `tree data/cats_dogs_dataset` to check the structure.

# %% [markdown]
# ### Support new dataset
#
# We have two methods to support a new dataset in MMClassification.
#
# The simplest method is to re-organize the new dataset as the format of a dataset supported officially (like `CustomDataset`). And you can also create a new dataset class. More details are in [the docs](https://mmclassification.readthedocs.io/en/dev-1.x/user_guides/dataset_prepare.html).
#
# In this tutorial, for convenience, we have re-organized the cats & dogs dataset as the format of `CustomDataset`.

# %% [markdown]
# Besides image files, it also includes the training/validation/test annotation files. And every line includes an file path and the corresponding label.
#
# ```
# ...
# cats/cat.3769.jpg 0
# cats/cat.882.jpg 0
# dogs/dog.3881.jpg 1
# dogs/dog.3377.jpg 1
# ...
# ```

# %%
# %%writefile configs/mobilenet_v2/mobilenet_v2_1x_cats_dogs.py
_base_ = [
    '../_base_/models/convnext/convnext-base.py',
    '../_base_/schedules/imagenet_bs1024_adamw_swin.py',
    '../_base_/default_runtime.py',
]
# ---- model settings ----
# Here we use init_cfg to load pre-trained model.
# In this way, only the weights of backbone will be loaded.
# And modify the num_classes to match our dataset.

model = dict(
    backbone=dict(
        init_cfg = dict(
            _delete_=True,
            type='Pretrained', 
            checkpoint='https://download.openmmlab.com/mmclassification/v0/mlp-mixer/mixer-base-p16_3rdparty_64xb64_in1k_20211124-1377e3e0.pth', 
            prefix='backbone')
    ),
    head=dict(num_classes=2))

# ---- data settings ----
# We re-organized the dataset as `CustomDataset` format.
dataset_type = 'CustomDataset'
data_preprocessor = dict(
    mean=[124.508, 116.050, 106.438],
    std=[58.577, 57.310, 57.437],
    to_rgb=True,
)

train_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='RandomResizedCrop', scale=224, backend='pillow'),
    dict(type='RandomFlip', prob=0.5, direction='horizontal'),
    dict(type='PackClsInputs'),
]
test_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='ResizeEdge', scale=256, edge='short', backend='pillow'),
    dict(type='CenterCrop', crop_size=224),
    dict(type='PackClsInputs'),
]

train_dataloader = dict(
    batch_size=64,
    num_workers=2,
    dataset=dict(
        type=dataset_type,
        data_prefix='data/cats_dogs_dataset/training_set/training_set',
        classes=['cat', 'dog'],
        pipeline=train_pipeline,
    ),
    sampler=dict(type='DefaultSampler', shuffle=True),
)

val_dataloader = dict(
    batch_size=64,
    num_workers=2,
    dataset=dict(
        type=dataset_type,
        data_prefix='data/cats_dogs_dataset/val_set/val_set',
        classes=['cat', 'dog'],
        pipeline=test_pipeline,
    ),
    sampler=dict(type='DefaultSampler', shuffle=False),
)

test_dataloader = dict(
    batch_size=64,
    num_workers=2,
    dataset=dict(
        type=dataset_type,
        data_prefix='data/cats_dogs_dataset/test_set/test_set',
        classes=['cat', 'dog'],
        pipeline=test_pipeline,
    ),
    sampler=dict(type='DefaultSampler', shuffle=False),
)

# Specify the evaluation metric for validation and testing.
val_evaluator = dict(type='Accuracy', topk=1)
test_evaluator = val_evaluator




# Set training epochs and validate interval.
train_cfg = dict(by_epoch=True, max_epochs=10, val_interval=1)
# Use default settings for validation and testing
val_cfg = dict()
test_cfg = dict()

# ---- runtime settings ----
# Output training log every 10 iterations.
default_hooks = dict(logger=dict(interval=10))

# If you want to ensure reproducibility, set a random seed. And enable the
# deterministic option in cuDNN to further ensure reproducibility, but it may
# reduce the training speed.
randomness = dict(seed=0, deterministic=False)
# Out:
# Overwriting configs/mobilenet_v2/mobilenet_v2_1x_cats_dogs.py

# %%
# !python tools/train.py \
  configs/mobilenet_v2/mobilenet_v2_1x_cats_dogs.py \
  --work-dir work_dirs/mobilenet_v2_1x_cats_dogs
# Out:
# 02/10 05:33:21 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Nov 14 2022, 12:59:47) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 0
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.6, V11.6.124
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.3.2  (built against CUDA 11.5)
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.6, CUDNN_VERSION=8.3.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.13.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.14.1+cu116
#     OpenCV: 4.6.0
#     MMEngine: 0.5.0
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 0
#     deterministic: False
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 02/10 05:33:22 - mmengine - INFO - Config:
# model = dict(
#     type='ImageClassifier',
#     backbone=dict(
#         type='ConvNeXt',
#         arch='base',
#         out_indices=(3, ),
#         drop_path_rate=0.5,
#         gap_before_final_norm=True,
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint=
#             'https://download.openmmlab.com/mmclassification/v0/mlp-mixer/mixer-base-p16_3rdparty_64xb64_in1k_20211124-1377e3e0.pth',
#             prefix='backbone')),
#     head=dict(
#         type='LinearClsHead',
#         num_classes=2,
#         in_channels=1024,
#         loss=dict(
#             type='LabelSmoothLoss', label_smooth_val=0.1, mode='original')),
#     train_cfg=dict(augments=[
#         dict(type='Mixup', alpha=0.8),
#         dict(type='CutMix', alpha=1.0)
#     ]))
# optim_wrapper = dict(
#     optimizer=dict(
#         type='AdamW',
#         lr=0.001,
#         weight_decay=0.05,
#         eps=1e-08,
#         betas=(0.9, 0.999)),
#     paramwise_cfg=dict(
#         norm_decay_mult=0.0,
#         bias_decay_mult=0.0,
#         flat_decay_mult=0.0,
#         custom_keys=dict({
#             '.absolute_pos_embed': dict(decay_mult=0.0),
#             '.relative_position_bias_table': dict(decay_mult=0.0)
#         })))
# param_scheduler = [
#     dict(
#         type='LinearLR',
#         start_factor=0.001,
#         by_epoch=True,
#         end=20,
#         convert_to_iter_based=True),
#     dict(type='CosineAnnealingLR', eta_min=1e-05, by_epoch=True, begin=20)
# ]
# train_cfg = dict(by_epoch=True, max_epochs=10, val_interval=1)
# val_cfg = dict()
# test_cfg = dict()
# auto_scale_lr = dict(base_batch_size=1024)
# default_scope = 'mmcls'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=10),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', interval=1),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='VisualizationHook', enable=False))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='ClsVisualizer', vis_backends=[dict(type='LocalVisBackend')])
# log_level = 'INFO'
# load_from = None
# resume = False
# randomness = dict(seed=0, deterministic=False)
# dataset_type = 'CustomDataset'
# data_preprocessor = dict(
#     mean=[124.508, 116.05, 106.438], std=[58.577, 57.31, 57.437], to_rgb=True)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='RandomResizedCrop', scale=224, backend='pillow'),
#     dict(type='RandomFlip', prob=0.5, direction='horizontal'),
#     dict(type='PackClsInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='ResizeEdge', scale=256, edge='short', backend='pillow'),
#     dict(type='CenterCrop', crop_size=224),
#     dict(type='PackClsInputs')
# ]
# train_dataloader = dict(
#     pin_memory=True,
#     persistent_workers=True,
#     collate_fn=dict(type='default_collate'),
#     batch_size=64,
#     num_workers=2,
#     dataset=dict(
#         type='CustomDataset',
#         data_prefix='data/cats_dogs_dataset/training_set/training_set',
#         classes=['cat', 'dog'],
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='RandomResizedCrop', scale=224, backend='pillow'),
#             dict(type='RandomFlip', prob=0.5, direction='horizontal'),
#             dict(type='PackClsInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=True))
# val_dataloader = dict(
#     pin_memory=True,
#     persistent_workers=True,
#     collate_fn=dict(type='default_collate'),
#     batch_size=64,
#     num_workers=2,
#     dataset=dict(
#         type='CustomDataset',
#         data_prefix='data/cats_dogs_dataset/val_set/val_set',
#         classes=['cat', 'dog'],
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='ResizeEdge', scale=256, edge='short', backend='pillow'),
#             dict(type='CenterCrop', crop_size=224),
#             dict(type='PackClsInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=False))
# test_dataloader = dict(
#     pin_memory=True,
#     persistent_workers=True,
#     collate_fn=dict(type='default_collate'),
#     batch_size=64,
#     num_workers=2,
#     dataset=dict(
#         type='CustomDataset',
#         data_prefix='data/cats_dogs_dataset/test_set/test_set',
#         classes=['cat', 'dog'],
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='ResizeEdge', scale=256, edge='short', backend='pillow'),
#             dict(type='CenterCrop', crop_size=224),
#             dict(type='PackClsInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=False))
# val_evaluator = dict(type='Accuracy', topk=1)
# test_evaluator = dict(type='Accuracy', topk=1)
# launcher = 'none'
# work_dir = 'work_dirs/mobilenet_v2_1x_cats_dogs'
#
# 02/10 05:33:22 - mmengine - WARNING - The "visualizer" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 02/10 05:33:22 - mmengine - WARNING - The "vis_backend" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 02/10 05:33:23 - mmengine - WARNING - The "model" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 02/10 05:33:23 - mmengine - WARNING - The "batch augment" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 02/10 05:33:23 - mmengine - INFO - Because batch augmentations are enabled, the data preprocessor automatically enables the `to_onehot` option to generate one-hot format labels.
# 02/10 05:33:27 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 02/10 05:33:27 - mmengine - WARNING - The "hook" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 02/10 05:33:27 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 02/10 05:33:28 - mmengine - WARNING - The "dataset" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 02/10 05:33:28 - mmengine - WARNING - The "transform" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 02/10 05:33:29 - mmengine - WARNING - The "data sampler" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 02/10 05:33:29 - mmengine - WARNING - The "optimizer wrapper constructor" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.downsample_layers.0.0.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.downsample_layers.0.1.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.downsample_layers.0.1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.downsample_layers.1.0.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.downsample_layers.1.0.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.downsample_layers.1.1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.downsample_layers.2.0.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.downsample_layers.2.0.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.downsample_layers.2.1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.downsample_layers.3.0.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.downsample_layers.3.0.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.downsample_layers.3.1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.0.0.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.0.0.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.0.0.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.0.0.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.0.0.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.0.0.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.0.1.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.0.1.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.0.1.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.0.1.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.0.1.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.0.1.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.0.2.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.0.2.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.0.2.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.0.2.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.0.2.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.0.2.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.1.0.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.1.0.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.1.0.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.1.0.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.1.0.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.1.0.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.1.1.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.1.1.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.1.1.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.1.1.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.1.1.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.1.1.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.1.2.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.1.2.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.1.2.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.1.2.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.1.2.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.1.2.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.0.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.0.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.0.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.0.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.0.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.0.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.1.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.1.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.1.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.1.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.1.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.1.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.2.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.2.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.2.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.2.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.2.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.2.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.3.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.3.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.3.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.3.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.3.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.3.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.4.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.4.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.4.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.4.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.4.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.4.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.5.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.5.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.5.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.5.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.5.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.5.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.6.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.6.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.6.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.6.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.6.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.6.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.7.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.7.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.7.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.7.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.7.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.7.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.8.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.8.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.8.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.8.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.8.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.8.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.9.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.9.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.9.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.9.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.9.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.9.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.10.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.10.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.10.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.10.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.10.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.10.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.11.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.11.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.11.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.11.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.11.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.11.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.12.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.12.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.12.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.12.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.12.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.12.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.13.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.13.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.13.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.13.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.13.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.13.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.14.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.14.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.14.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.14.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.14.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.14.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.15.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.15.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.15.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.15.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.15.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.15.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.16.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.16.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.16.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.16.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.16.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.16.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.17.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.17.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.17.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.17.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.17.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.17.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.18.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.18.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.18.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.18.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.18.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.18.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.19.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.19.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.19.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.19.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.19.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.19.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.20.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.20.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.20.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.20.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.20.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.20.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.21.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.21.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.21.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.21.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.21.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.21.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.22.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.22.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.22.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.22.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.22.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.22.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.23.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.23.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.23.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.23.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.23.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.23.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.24.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.24.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.24.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.24.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.24.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.24.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.25.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.25.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.25.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.25.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.25.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.25.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.26.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.26.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.26.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.26.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.26.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.2.26.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.3.0.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.3.0.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.3.0.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.3.0.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.3.0.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.3.0.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.3.1.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.3.1.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.3.1.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.3.1.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.3.1.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.3.1.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.3.2.gamma:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.3.2.depthwise_conv.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.3.2.norm.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.3.2.norm.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.3.2.pointwise_conv1.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.stages.3.2.pointwise_conv2.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.norm3.weight:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- backbone.norm3.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - INFO - paramwise_options -- head.fc.bias:weight_decay=0.0
# 02/10 05:33:29 - mmengine - WARNING - The "optimizer" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 02/10 05:33:29 - mmengine - WARNING - The "optimizer_wrapper" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 02/10 05:33:29 - mmengine - WARNING - The "parameter scheduler" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/mmengine/registry/build_functions.py", line 121, in build_from_cfg
#     obj = obj_cls(**args)  # type: ignore
#   File "/usr/local/lib/python3.8/dist-packages/mmengine/optim/scheduler/lr_scheduler.py", line 20, in __init__
#     super().__init__(optimizer, 'lr', *args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/mmengine/optim/scheduler/param_scheduler.py", line 641, in __init__
#     super().__init__(
#   File "/usr/local/lib/python3.8/dist-packages/mmengine/optim/scheduler/param_scheduler.py", line 68, in __init__
#     raise ValueError('end should be larger than begin, but got'
# ValueError: end should be larger than begin, but got begin=20, end=10
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "tools/train.py", line 162, in <module>
#     main()
#   File "tools/train.py", line 158, in main
#     runner.train()
#   File "/usr/local/lib/python3.8/dist-packages/mmengine/runner/runner.py", line 1666, in train
#     self.param_schedulers = self.build_param_scheduler(  # type: ignore
#   File "/usr/local/lib/python3.8/dist-packages/mmengine/runner/runner.py", line 1225, in build_param_scheduler
#     param_schedulers = self._build_param_scheduler(
#   File "/usr/local/lib/python3.8/dist-packages/mmengine/runner/runner.py", line 1142, in _build_param_scheduler
#     PARAM_SCHEDULERS.build(
#   File "/usr/local/lib/python3.8/dist-packages/mmengine/registry/registry.py", line 521, in build
#     return self.build_func(cfg, *args, **kwargs, registry=self)
#   File "/usr/local/lib/python3.8/dist-packages/mmengine/registry/build_functions.py", line 306, in build_scheduler_from_cfg
#     return build_from_cfg(args, registry)
#   File "/usr/local/lib/python3.8/dist-packages/mmengine/registry/build_functions.py", line 135, in build_from_cfg
#     raise type(e)(
# ValueError: class `CosineAnnealingLR` in mmengine/optim/scheduler/lr_scheduler.py: end should be larger than begin, but got begin=20, end=10

# %%
# !python tools/test.py configs/mobilenet_v2/mobilenet_v2_1x_cats_dogs.py work_dirs/mobilenet_v2_1x_cats_dogs/epoch_2.pth --dump result.pkl
# Out:
# 02/10 05:31:21 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Nov 14 2022, 12:59:47) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 0
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.6, V11.6.124
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.3.2  (built against CUDA 11.5)
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.6, CUDNN_VERSION=8.3.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.13.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.14.1+cu116
#     OpenCV: 4.6.0
#     MMEngine: 0.5.0
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 0
#     deterministic: False
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 02/10 05:31:22 - mmengine - INFO - Config:
# model = dict(
#     type='ImageClassifier',
#     backbone=dict(
#         type='MlpMixer',
#         arch='b',
#         img_size=224,
#         patch_size=16,
#         drop_rate=0.1,
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint=
#             'https://download.openmmlab.com/mmclassification/v0/mlp-mixer/mixer-base-p16_3rdparty_64xb64_in1k_20211124-1377e3e0.pth',
#             prefix='backbone')),
#     neck=dict(type='GlobalAveragePooling', dim=1),
#     head=dict(
#         type='LinearClsHead',
#         num_classes=2,
#         in_channels=768,
#         loss=dict(type='CrossEntropyLoss', loss_weight=1.0),
#         topk=(1, 5)))
# optim_wrapper = dict(
#     optimizer=dict(type='AdamW', lr=0.003, weight_decay=0.3),
#     paramwise_cfg=dict(
#         custom_keys=dict({
#             '.cls_token': dict(decay_mult=0.0),
#             '.pos_embed': dict(decay_mult=0.0)
#         })))
# param_scheduler = [
#     dict(
#         type='LinearLR',
#         start_factor=0.0001,
#         by_epoch=True,
#         begin=0,
#         end=30,
#         convert_to_iter_based=True),
#     dict(
#         type='CosineAnnealingLR', T_max=270, by_epoch=True, begin=30, end=300)
# ]
# train_cfg = dict(by_epoch=True, max_epochs=10, val_interval=1)
# val_cfg = dict()
# test_cfg = dict()
# auto_scale_lr = dict(base_batch_size=4096)
# default_scope = 'mmcls'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=10),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', interval=1),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='VisualizationHook', enable=False))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='ClsVisualizer', vis_backends=[dict(type='LocalVisBackend')])
# log_level = 'INFO'
# load_from = 'work_dirs/mobilenet_v2_1x_cats_dogs/epoch_2.pth'
# resume = False
# randomness = dict(seed=0, deterministic=False)
# dataset_type = 'CustomDataset'
# data_preprocessor = dict(
#     mean=[124.508, 116.05, 106.438], std=[58.577, 57.31, 57.437], to_rgb=True)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='RandomResizedCrop', scale=224, backend='pillow'),
#     dict(type='RandomFlip', prob=0.5, direction='horizontal'),
#     dict(type='PackClsInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='ResizeEdge', scale=256, edge='short', backend='pillow'),
#     dict(type='CenterCrop', crop_size=224),
#     dict(type='PackClsInputs')
# ]
# train_dataloader = dict(
#     batch_size=64,
#     num_workers=2,
#     dataset=dict(
#         type='CustomDataset',
#         data_prefix='data/cats_dogs_dataset/training_set/training_set',
#         classes=['cat', 'dog'],
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='RandomResizedCrop', scale=224, backend='pillow'),
#             dict(type='RandomFlip', prob=0.5, direction='horizontal'),
#             dict(type='PackClsInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=True))
# val_dataloader = dict(
#     batch_size=64,
#     num_workers=2,
#     dataset=dict(
#         type='CustomDataset',
#         data_prefix='data/cats_dogs_dataset/val_set/val_set',
#         classes=['cat', 'dog'],
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='ResizeEdge', scale=256, edge='short', backend='pillow'),
#             dict(type='CenterCrop', crop_size=224),
#             dict(type='PackClsInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=False))
# test_dataloader = dict(
#     pin_memory=True,
#     collate_fn=dict(type='default_collate'),
#     batch_size=64,
#     num_workers=2,
#     dataset=dict(
#         type='CustomDataset',
#         data_prefix='data/cats_dogs_dataset/test_set/test_set',
#         classes=['cat', 'dog'],
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='ResizeEdge', scale=256, edge='short', backend='pillow'),
#             dict(type='CenterCrop', crop_size=224),
#             dict(type='PackClsInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=False))
# val_evaluator = dict(type='Accuracy', topk=1)
# test_evaluator = [
#     dict(type='Accuracy', topk=1),
#     dict(type='DumpResults', out_file_path='result.pkl')
# ]
# launcher = 'none'
# work_dir = './work_dirs/mobilenet_v2_1x_cats_dogs'
#
# 02/10 05:31:22 - mmengine - WARNING - The "visualizer" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 02/10 05:31:22 - mmengine - WARNING - The "vis_backend" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 02/10 05:31:23 - mmengine - WARNING - The "model" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 02/10 05:31:25 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 02/10 05:31:25 - mmengine - WARNING - The "hook" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 02/10 05:31:25 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 02/10 05:31:26 - mmengine - WARNING - The "dataset" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 02/10 05:31:26 - mmengine - WARNING - The "transform" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 02/10 05:31:26 - mmengine - WARNING - The "data sampler" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 02/10 05:31:26 - mmengine - WARNING - The "metric" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# /usr/local/lib/python3.8/dist-packages/mmengine/evaluator/metric.py:47: UserWarning: The prefix is not set in metric class DumpResults.
#   warnings.warn('The prefix is not set in metric class '
# Loads checkpoint by local backend from path: work_dirs/mobilenet_v2_1x_cats_dogs/epoch_2.pth
# 02/10 05:31:30 - mmengine - INFO - Load checkpoint from work_dirs/mobilenet_v2_1x_cats_dogs/epoch_2.pth
# 02/10 05:31:38 - mmengine - INFO - Epoch(test) [10/32]    eta: 0:00:17  time: 0.7955  data_time: 0.0881  memory: 705
# 02/10 05:31:43 - mmengine - INFO - Epoch(test) [20/32]    eta: 0:00:07  time: 0.5138  data_time: 0.0025  memory: 705
# 02/10 05:31:48 - mmengine - INFO - Epoch(test) [30/32]    eta: 0:00:01  time: 0.5110  data_time: 0.0034  memory: 705
# 02/10 05:31:50 - mmengine - INFO - Results has been saved to result.pkl.
# 02/10 05:31:50 - mmengine - INFO - Epoch(test) [32/32]  accuracy/top1: 68.4132

# %%
import mmengine

results = mmengine.load("result.pkl")
# Output the first samples' ground truth and prediction.
print('Ground truth:', results[3]['gt_label'])
print('Prediction:', results[3]['pred_label'])
# Out:
# Ground truth: {'label': tensor([0])}
# Prediction: {'score': tensor([0.1041, 0.8959]), 'label': tensor([1])}

# %% [markdown]
# ### Inference with a model
#
# Sometimes we want to save the inference results on a image, just use the command below.
#
# ```shell
# python demo/image_demo.py ${IMAGE_FILE} ${CONFIG_FILE} ${CHECKPOINT_FILE}
# ```

# %%
# !python demo/image_demo.py data/cats_dogs_dataset/training_set/training_set/cats/cat.1.jpg configs/mobilenet_v2/mobilenet_v2_1x_cats_dogs.py work_dirs/mobilenet_v2_1x_cats_dogs/epoch_2.pth
# Out:
# local loads checkpoint from path: work_dirs/mobilenet_v2_1x_cats_dogs/epoch_2.pth
# {
#   "pred_label": 0,
#   "pred_score": 1.0,
#   "pred_scores": [
#     1.0,
#     1.7860038781236653e-08
#   ],
#   "pred_class": "cat"
# }
